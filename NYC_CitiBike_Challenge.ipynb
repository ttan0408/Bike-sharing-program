# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 

#File to load
citibike_data_to_load = "Resources/201908_citibike_tripdata.csv"

#Read the citibike data , and store it in a Pandas Dataframe.
citibike_data_df = pd.read_csv(citibike_data_to_load)

# %%
# 2. Check the datatypes of your columns. 
citibike_data_df.tail(10)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2344214           532  2019-08-31 23:59:36.1200  2019-09-01 00:08:28.7850
# 2344215           838  2019-08-31 23:59:38.0510  2019-09-01 00:13:36.8530
# 2344216           231  2019-08-31 23:59:39.0230  2019-09-01 00:03:30.4820
# 2344217           689  2019-08-31 23:59:41.4140  2019-09-01 00:11:10.8430
# 2344218          1767  2019-08-31 23:59:45.7730  2019-09-01 00:29:13.6000
# 2344219           216  2019-08-31 23:59:46.2930  2019-09-01 00:03:23.0360
# 2344220           117  2019-08-31 23:59:47.7970  2019-09-01 00:01:45.7440
# 2344221          1614  2019-08-31 23:59:48.1560  2019-09-01 00:26:42.7760
# 2344222          1301  2019-08-31 23:59:58.3620  2019-09-01 00:21:39.7040
# 2344223           419  2019-08-31 23:59:59.4520  2019-09-01 00:06:59.0210
#
#          start station id            start station name  \
# 2344214            3323.0  W 106 St & Central Park West
# ...

# %%
citibike_data_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citibike_data_df['tripduration'] = pd.to_datetime(citibike_data_df['tripduration'], unit='D')

# %%
# 4. Check the datatypes of your columns. 
citibike_data_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
citibike_data_df.tail(10)
# Out:
#                tripduration                 starttime  \
# 2344214 1970-01-01 08:52:00  2019-08-31 23:59:36.1200
# 2344215 1970-01-01 13:58:00  2019-08-31 23:59:38.0510
# 2344216 1970-01-01 03:51:00  2019-08-31 23:59:39.0230
# 2344217 1970-01-01 11:29:00  2019-08-31 23:59:41.4140
# 2344218 1970-01-02 05:27:00  2019-08-31 23:59:45.7730
# 2344219 1970-01-01 03:36:00  2019-08-31 23:59:46.2930
# 2344220 1970-01-01 01:57:00  2019-08-31 23:59:47.7970
# 2344221 1970-01-02 02:54:00  2019-08-31 23:59:48.1560
# 2344222 1970-01-01 21:41:00  2019-08-31 23:59:58.3620
# 2344223 1970-01-01 06:59:00  2019-08-31 23:59:59.4520
#
#                          stoptime  start station id  \
# 2344214  2019-09-01 00:08:28.7850            3323.0
# 2344215  2019-09-01 00:13:36.8530            3094.0
# 2344216  2019-09-01 00:03:30.4820             293.0
# 2344217  2019-09-01 00:11:10.8430             341.0
# 2344218  2019-09-01 00:29:13.6000             403.0
# ...

# %%
citibike_data_df.to_csv(r'Resources/201908_citibike_tripdata_2.csv', index = False)
